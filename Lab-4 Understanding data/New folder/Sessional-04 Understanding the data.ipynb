# %% [markdown]
# ## Welcome to the fourth lab of the Data Mining course! In this lab, we will work with two datasets to explore various aspects of data manipulation, statistics, and visualization using Python.
# ---

# %%
import pandas as pd

# Load data from CSV file
brain_size_df = pd.read_csv('/content/brain_size.csv')

# %%
# Shape of the DataFrame
shape = brain_size_df.shape

# %%
# Shape of the DataFrame
shape = brain_size_df.shape
print("Shape of the DataFrame:", shape)

# Number of columns in the DataFrame
num_columns = len(brain_size_df.columns)
print("Number of columns:", num_columns)

# Mean of numerical attributes
mean_values = brain_size_df.mean()
print("Mean values:")
print(mean_values)
# Out:
# Shape of the DataFrame: (40, 1)
# Number of columns: 1
# Mean values:
# Series([], dtype: float64)
# <ipython-input-10-6dcaf88d279d>:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = brain_size_df.mean()

# %%
from google.colab import drive
drive.mount('/content/drive')
