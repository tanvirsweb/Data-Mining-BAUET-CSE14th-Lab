# %% [markdown]
# # IRIS Dataset

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Load the iris dataset
data_path = 'C:\\Users\\Hp\\Documents\\CSE-4250\\Lab 11 Confusion_Matrix\\iris.csv'
df = pd.read_csv(data_path)

# %%
df
# Out:
#       ID  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0      1           5.1          3.5           1.4          0.2     setosa
# 1      2           4.9          3.0           1.4          0.2     setosa
# 2      3           4.7          3.2           1.3          0.2     setosa
# 3      4           4.6          3.1           1.5          0.2     setosa
# 4      5           5.0          3.6           1.4          0.2     setosa
# ..   ...           ...          ...           ...          ...        ...
# 145  146           6.7          3.0           5.2          2.3  virginica
# 146  147           6.3          2.5           5.0          1.9  virginica
# 147  148           6.5          3.0           5.2          2.0  virginica
# 148  149           6.2          3.4           5.4          2.3  virginica
# 149  150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 6 columns]

# %%
# Separate features and target
X = df.drop('Species', axis=1)
y = df['Species']

# %%
# Set up K-Fold Cross-Validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
model = RandomForestClassifier(random_state=42)

# %%
# List to store accuracy of each fold
accuracies = []

# Perform K-Fold Cross-Validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Train the model
    model.fit(X_train, y_train)

# %%
  
    # Make predictions and calculate accuracy
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

# %%
# Print the accuracy for each fold and the average accuracy
for i, acc in enumerate(accuracies, 1):
    print(f"Fold {i}: Accuracy = {acc:.4f}")

print(f"\nAverage Accuracy: {sum(accuracies) / len(accuracies):.4f}")
# Out:
# Fold 1: Accuracy = 1.0000
#
# Average Accuracy: 1.0000

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# Load the Iris dataset
data_path = 'C:\\Users\\Hp\\Documents\\CSE-4250\\Lab 11 Confusion_Matrix\\iris.csv'
df = pd.read_csv(data_path)

# Separate features and target
X = df.drop('Species', axis=1)
y = df['Species']

# Function to perform K-Fold Cross-Validation and print results
def perform_k_fold_cv(X, y, k, model):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    accuracies = []
    
    print(f"\nPerforming {k}-Fold Cross-Validation:")

    for fold, (train_index, test_index) in enumerate(kf.split(X), 1):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Train the model
        model.fit(X_train, y_train)
        
        # Make predictions and calculate accuracy
        y_pred = model.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        
        # Print accuracy for each fold
        print(f"Fold {fold}: Accuracy = {accuracy:.4f}")

    # Print the average accuracy
    average_accuracy = sum(accuracies) / len(accuracies)
    print(f"\nAverage Accuracy for {k}-Fold: {average_accuracy:.4f}")
    return average_accuracy

# Define the model
model = RandomForestClassifier(random_state=42)

# Perform 5-Fold Cross-Validation
perform_k_fold_cv(X, y, k=5, model=model)

# Perform 10-Fold Cross-Validation
perform_k_fold_cv(X, y, k=10, model=model)
# Out:
# Performing 5-Fold Cross-Validation:
# Fold 1: Accuracy = 1.0000
# Fold 2: Accuracy = 1.0000
# Fold 3: Accuracy = 1.0000
# Fold 4: Accuracy = 1.0000
# Fold 5: Accuracy = 1.0000
#
# Average Accuracy for 5-Fold: 1.0000
#
# Performing 10-Fold Cross-Validation:
# Fold 1: Accuracy = 1.0000
# Fold 2: Accuracy = 1.0000
# Fold 3: Accuracy = 1.0000
# Fold 4: Accuracy = 1.0000
# Fold 5: Accuracy = 1.0000
# Fold 6: Accuracy = 1.0000
# Fold 7: Accuracy = 1.0000
# Fold 8: Accuracy = 1.0000
# Fold 9: Accuracy = 1.0000
# Fold 10: Accuracy = 1.0000
#
# Average Accuracy for 10-Fold: 1.0000
# 1.0

# %% [markdown]
# # winequality Dataset

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelBinarizer

# Load the Wine Quality dataset
#data_path = 'path_to_your_file/winequality-red.csv'  # Replace with your file path
data_path = 'C:\\Users\\Hp\\Documents\\CSE-4250\\Lab 11 Confusion_Matrix\\winequality-red.csv'
df = pd.read_csv(data_path, delimiter=';')

# Convert quality scores to binary classification for simplicity
# Here, we consider wine with quality >= 6 as 'Good' (1) and < 6 as 'Bad' (0)
df['quality'] = df['quality'].apply(lambda x: 1 if x >= 6 else 0)

# Separate features and target
X = df.drop('quality', axis=1)
y = df['quality']

# Function to perform K-Fold Cross-Validation and print results
def perform_k_fold_cv(X, y, k, model):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    accuracies = []
    
    print(f"\nPerforming {k}-Fold Cross-Validation:")

    for fold, (train_index, test_index) in enumerate(kf.split(X), 1):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Train the model
        model.fit(X_train, y_train)
        
        # Make predictions and calculate accuracy
        y_pred = model.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        
        # Print accuracy for each fold
        print(f"Fold {fold}: Accuracy = {accuracy:.4f}")

    # Print the average accuracy
    average_accuracy = sum(accuracies) / len(accuracies)
    print(f"\nAverage Accuracy for {k}-Fold: {average_accuracy:.4f}")
    return average_accuracy

# Define the model
model = RandomForestClassifier(random_state=42)

# Perform 5-Fold Cross-Validation
perform_k_fold_cv(X, y, k=5, model=model)

# Perform 10-Fold Cross-Validation
perform_k_fold_cv(X, y, k=10, model=model)
# Out:
# Performing 5-Fold Cross-Validation:
# Fold 1: Accuracy = 0.7844
# Fold 2: Accuracy = 0.8250
# Fold 3: Accuracy = 0.7844
# Fold 4: Accuracy = 0.8250
# Fold 5: Accuracy = 0.8715
#
# Average Accuracy for 5-Fold: 0.8180
#
# Performing 10-Fold Cross-Validation:
# Fold 1: Accuracy = 0.8187
# Fold 2: Accuracy = 0.7937
# Fold 3: Accuracy = 0.8313
# Fold 4: Accuracy = 0.8125
# Fold 5: Accuracy = 0.8313
# Fold 6: Accuracy = 0.7750
# Fold 7: Accuracy = 0.8500
# Fold 8: Accuracy = 0.8000
# Fold 9: Accuracy = 0.8875
# Fold 10: Accuracy = 0.8679
#
# Average Accuracy for 10-Fold: 0.8268
# 0.8267924528301887
